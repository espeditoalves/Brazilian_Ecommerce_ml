# %%
import sys
import os
from pathlib import Path

print(sys.executable)
# Out:
# c:\Users\esped\Projects\Brazilian_Ecommerce_ml\.venv\Scripts\python.exe

# %%
# Adiciona o diretório raiz ao PYTHONPATH
project_root = Path.cwd().parent.parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from src.data.raw import download_raw_data

# Baixa os dados e copia para a pasta data/raw
download_raw_data()
# Out:
# Iniciando o download do dataset do Kaggle...
# Downloading to C:\Users\esped\.cache\kagglehub\datasets\olistbr\brazilian-ecommerce\2.archive...
# 100%|██████████| 42.6M/42.6M [00:02<00:00, 19.8MB/s]
# Extracting files...
# Arquivos baixados no cache: C:\Users\esped\.cache\kagglehub\datasets\olistbr\brazilian-ecommerce\versions\2
# Movendo arquivos para: C:\Users\esped\Projects\Brazilian_Ecommerce_ml\data\raw
#  - Movido: olist_customers_dataset.csv
#  - Movido: olist_geolocation_dataset.csv
#  - Movido: olist_orders_dataset.csv
#  - Movido: olist_order_items_dataset.csv
#  - Movido: olist_order_payments_dataset.csv
#  - Movido: olist_order_reviews_dataset.csv
#  - Movido: olist_products_dataset.csv
#  - Movido: olist_sellers_dataset.csv
#  - Movido: product_category_name_translation.csv
#
# Download e organização concluídos com sucesso!
# Total de arquivos movidos: 9
# Diretório removido com sucesso: C:\Users\esped\.cache\kagglehub\datasets
